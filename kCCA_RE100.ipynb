# %%
InteractionsFileCaptureC='/srv/gsfs0/projects/kundaje/users/mtaranov/projects/dynamic3D/ContactsAfterIC/ChiCAGO_Calls_Adam/analysis/CaptureC_SC_bait-bait.bed.gz'
InteractionsFileHiC='/srv/gsfs0/projects/kundaje/users/mtaranov/projects/dynamic3D/ContactsAfterIC/P-P_from_HiC/output/PP_SC_RE100.bed.gz'
PromoterFile='/srv/gsfs0/projects/kundaje/users/mtaranov/projects/dynamic3D/FIT-HI-C/promoters_flexible_repl_combined/data/reference_genomes/hg19/PromoterCapture_Digest_Human_HindIII_baits_ID.bed'
PROJDIR='/srv/gsfs0/projects/kundaje/users/mtaranov/projects/dynamic3D/ContactsAfterIC/kCCA'

# %%
# %matplotlib inline
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.stats.mstats import mquantiles
import math
import scipy.linalg
import itertools
import copy
import random
import gzip
import rcca

# %%
# builds adjacency matrix 
def BuildMatrixA(PromoterFile, InteractionsFile, datatype):

    REFrag_dict={}
    index=0
    # Assign indices to all promoter HindIII sites.
    for line in open(PromoterFile,'r'):
        words=line.rstrip().split()
        key=(words[0], words[1], words[2])
        if words[0] in ['chr1']: # only chr1
           REFrag_dict[key]=index
           index+=1

    # Initialize matrix (promoter x promoter)
    PPMatrix=np.zeros((len(REFrag_dict), len(REFrag_dict))) #  number of promoters in chr 1

    # Fill (promoter x promoter) matrix with q-values of promoter-promoter interaction
    for line in gzip.open(InteractionsFile,'r'):
        words=line.rstrip().split()
        if words[0] in ['chr1']: #only chr1
            i=REFrag_dict[(words[0], words[1], words[2])]
            j=REFrag_dict[(words[3], words[4], words[5])]
            if datatype == 'HiC':
                q_values=1.0-float(words[6]) # for HiC
            else:
                q_values=1.0-math.pow(10.0,-1*float(words[6]))  # for CaptureC
            if PPMatrix[i,j] != 0:
                PPMatrix[i,j]=PPMatrix[i,j]/2+q_values/2
                PPMatrix[j,i]=PPMatrix[j,i]/2+q_values/2
            else:
                PPMatrix[i,j]=q_values
                PPMatrix[j,i]=q_values
                    # take -1*log(Q) for non-zero entries
    #mask = PPMatrix != 0
    #PPMatrix[mask] = np.log10(PPMatrix[mask])*(-1)

    # list of non-zero q-values
    q_values=list(filter((0.0).__ne__,list(itertools.chain.from_iterable(np.array(PPMatrix).tolist()))))

    # Some tests:
    print "Some tests on adjacency matrix:"
    # 1. Check if the matrix is symmetric:
    if (PPMatrix.transpose() == PPMatrix).all() == True:
        print "Adjacency matrix is symmetric"
    # 2. Print out average q-values:
    print "Average q-value with zeros: ", str(np.average(PPMatrix))
    print "Average q-value w/o zeros: ", np.mean(q_values)

    # Print distribution of q-values
    plt.hist(q_values)
    plt.show()

    return PPMatrix

# %%
def DiffusionKernel(AdjMatrix, beta):
    # 1.Computes Degree matrix  - diagonal matrix with diagonal entries = raw sums of adjacency matrix 
    DegreeMatrix = np.diag(np.sum(AdjMatrix, axis=1))
    # 2. Computes negative Laplacian H = AdjMatrix - DegreeMatrix
    H = np.subtract(AdjMatrix, DegreeMatrix)
    # 3. Computes matrix exponential: exp(beta*H)
    K = scipy.linalg.expm(beta*H)

   # tests:
   # plot cummulative (1-q)-value (raw sums) for all promoters
    plt.plot(np.sum(AdjMatrix, axis=1))
    plt.xlim(0, len(AdjMatrix))
    plt.show()
    return K

# %%
def printMatrix(Matrix, ylabel, QuantileValue, LowerUpperLimit):
    #vmaxLim=mquantiles(Matrix,[0.99])[0]
    Lim=mquantiles(Matrix,[QuantileValue])[0]
    print Matrix.max()
    print np.shape(Matrix)
    print "Limit:", Lim
    fig, ax = plt.subplots()
    fig.subplots_adjust(top=0.8)
    if LowerUpperLimit == 'lower':
        m = ax.matshow(Matrix, origin="bottom", #norm=colors.LogNorm(),  #norm=colors.SymLogNorm(1),
               cmap="RdYlBu_r", vmin=Lim)
    else:
        m = ax.matshow(Matrix, origin="bottom", #norm=colors.LogNorm(),  #norm=colors.SymLogNorm(1),
               cmap="RdYlBu_r", vmax=Lim) # cmap="RdYlBu_r"


    ax.axhline(-0.5, color="#000000", linewidth=1, linestyle="--")
    ax.axvline(-0.5, color="#000000", linewidth=1, linestyle="--")

    cb = fig.colorbar(m)
    cb.set_label(ylabel)

    ax.set_ylim((-0.5, len(Matrix) - 0.5))
    ax.set_xlim((-0.5, len(Matrix) - 0.5))

    plt.show()
    return

# %%
PPMatrixCaptureC = BuildMatrixA(PromoterFile, InteractionsFileCaptureC, 'CaptureC')
printMatrix(PPMatrixCaptureC, '1-q_value', 1, 'upper')
DiffKMatrix10CaptureC=DiffusionKernel(PPMatrixCaptureC, 10)
DiffKMatrix1CaptureC=DiffusionKernel(PPMatrixCaptureC, 1)
Difference110CaptureC=np.subtract(DiffKMatrix10CaptureC, DiffKMatrix1CaptureC)
printMatrix(Difference110CaptureC, 'Exp(10*H)-Exp(1*H)', 0.001, 'lower')
# Out:
# Some tests on adjacency matrix:
# Adjacency matrix is symmetric
# Average q-value with zeros:  0.00601991780595
# Average q-value w/o zeros:  0.699849542714
# 1.0
# (2272, 2272)
# Limit: 1.0
# 0.259821124295
# (2272, 2272)
# Limit: -0.0235027433473

# %%
PPMatrixHiC = BuildMatrixA(PromoterFile, InteractionsFileHiC, 'HiC')
printMatrix(PPMatrixHiC, '1-q_value', 1, 'upper')
DiffKMatrix10HiC=DiffusionKernel(PPMatrixHiC, 10)
DiffKMatrix1HiC=DiffusionKernel(PPMatrixHiC, 1)
Difference110HiC=np.subtract(DiffKMatrix10HiC, DiffKMatrix1HiC)
printMatrix(Difference110HiC, 'Exp(10*H)-Exp(1*H)', 0.001, 'lower')
# Out:
# Some tests on adjacency matrix:
# Adjacency matrix is symmetric
# Average q-value with zeros:  0.00270071356414
# Average q-value w/o zeros:  0.880783434843
# 1.0
# (2272, 2272)
# Limit: 1.0
# 0.00397724834049
# (2272, 2272)
# Limit: -0.0054397874974

# %%
#test proportion is computed as total-train-vali
#nodes is an array of indices
def train_vali_test(PPMatrix, trainProportion,valiProportion):
    total_num=len(PPMatrix)
    train_num=int(trainProportion*total_num)
    vali_num=int(valiProportion*total_num)
    test_num=total_num-train_num-vali_num
    if test_num<=0:
        print "Nothing in the test set!!!"
    print "Training set: "+str(train_num)
    print "Validation set: "+str(vali_num)
    print "Test set: "+str(test_num)
    #decide the random split of nodes
    nodes = [i for i in range(len(PPMatrix))]
    shuffled_nodes=copy.copy(nodes)
    random.shuffle(shuffled_nodes)
    train_nodes=np.array(shuffled_nodes[:train_num])
    vali_nodes=np.array(shuffled_nodes[train_num:(train_num+vali_num)])
    test_nodes=np.array(shuffled_nodes[(train_num+vali_num):])
    #split each dataset based on the decided split
    def split_data(nodes , PPMatrix, train_num):
        subSampledMatrix=PPMatrix[nodes, :(train_num-1)]
        #subSampledMatrix=PPMatrix[nodes, :math.ceil(len(PPMatrix)/20)]
        return subSampledMatrix
    train = split_data(train_nodes, PPMatrix, train_num)
    vali = split_data(vali_nodes, PPMatrix, train_num)
    test = split_data(test_nodes, PPMatrix, train_num)
    print "Training:", np.shape(train), "Validation:", np.shape(vali), "Test:", np.shape(test)
    return train, vali, test

# %%
def run_cca(data1, data2, test1, test2, numCC,reg, title):
    cca = rcca.CCA(kernelcca=False, numCC=numCC, reg=reg)
    cca.train([data1, data2])
    # Find canonical components
    # Test on held-out data
    corrs = cca.validate([test1, test2])

    fig = plt.figure()
    ax = fig.add_subplot(111)
    plot0 = ax.bar(np.arange(corrs[0].shape[0]), corrs[0], 0.3, color = "steelblue")
    #plot1 = ax.bar(np.arange(corrs[1].shape[0])+0.35, corrs[1], 0.3, color="orangered")
    #ax.legend([plot0[0], plot1[0]], ["Dataset 1", "Dataset 2"])
    ax.set_title(title) 
    ax.set_ylabel("Prediction correlation")
    #ax.set_xticks(np.arange(0, corrs[0].shape[0], 20)+0.325)
    #ax.set_xticklabels(["%d" % i for i in range(0, corrs[0].shape[0], 20)])
    ax.set_xlabel("Test data")
    fig.savefig(str(PROJDIR)+'/Prediction.png', dpi=fig.dpi)
    return cca.train([data1, data2])

# %% [markdown]
# ### CaptureC with Diffusion Kernel

# %%
trainCaptureC_D1, valiCaptureC_D1, testCaptureC_D1 = train_vali_test(DiffKMatrix1CaptureC, 0.7, 0.2)
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testCaptureC_D1, 2, 1, 'Train: CaptureC-D1, Test: CaptureC-D1, CC=2')
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testCaptureC_D1, 10, 1, 'Train: CaptureC-D1, Test: CaptureC-D1, CC=10') 
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testCaptureC_D1, 20, 1, 'Train: CaptureC-D1, Test: CaptureC-D1, CC=20')

#run_cca(trainHiC, trainHiC, testHiC, testHiC, 2, 1)
#run_cca(trainCaptureC, trainCaptureC, testHiC, testHiC, 2, 1)
#run_cca(trainCaptureC, trainHiC, testHiC, testHiC, 2, 1)
# Out:
# Training set: 1590
# Validation set: 454
# Test set: 228
# Training: (1590, 1589) Validation: (454, 1589) Test: (228, 1589)
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 20 components
# Training CCA, regularization = 1.0000, 20 components

# %% [markdown]
# ### CaptureC

# %%
trainCaptureC, valiCaptureC, testCaptureC = train_vali_test(PPMatrixCaptureC, 0.7, 0.2)
run_cca(trainCaptureC, trainCaptureC, testCaptureC, testCaptureC, 2, 1, 'Train: CaptureC, Test: CaptureC, CC=2')
run_cca(trainCaptureC, trainCaptureC, testCaptureC, testCaptureC, 10, 1, 'Train: CaptureC, Test: CaptureC, CC=10')
run_cca(trainCaptureC, trainCaptureC, testCaptureC, testCaptureC, 20, 1, 'Train: CaptureC, Test: CaptureC, CC=20')
# Out:
# rcca.py:262: RuntimeWarning: invalid value encountered in divide
#   def _zscore(d): return (d-d.mean(0))/d.std(0)
# /srv/gs1/software/python/python-2.7/lib/python2.7/site-packages/numpy/lib/function_base.py:1957: RuntimeWarning: invalid value encountered in true_divide
#   return c / sqrt(multiply.outer(d, d))
# Training set: 1590
# Validation set: 454
# Test set: 228
# Training: (1590, 1589) Validation: (454, 1589) Test: (228, 1589)
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 20 components
# Training CCA, regularization = 1.0000, 20 components

# %% [markdown]
# ### HiC with Diffusion Kernel

# %%
trainHiC_D1, valiHiC_D1, testHiC_D1 = train_vali_test(DiffKMatrix1HiC, 0.7, 0.2)
run_cca(trainHiC_D1, trainHiC_D1, testHiC_D1, testHiC_D1, 2, 1, 'Train: HiC-D1, Test: HiC-D1, CC=2')
run_cca(trainHiC_D1, trainHiC_D1, testHiC_D1, testHiC_D1, 10, 1, 'Train: HiC-D1, Test: HiC-D1, CC=10') 
run_cca(trainHiC_D1, trainHiC_D1, testHiC_D1, testHiC_D1, 20, 1, 'Train: HiC-D1, Test: HiC-D1, CC=20')
# Out:
# Training set: 1590
# Validation set: 454
# Test set: 228
# Training: (1590, 1589) Validation: (454, 1589) Test: (228, 1589)
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 20 components
# Training CCA, regularization = 1.0000, 20 components

# %% [markdown]
# ### HiC

# %%
trainHiC, valiHiC, testHiC = train_vali_test(PPMatrixHiC, 0.7, 0.2)
run_cca(trainHiC, trainHiC, testHiC, testHiC, 2, 1, 'Train: HiC, Test: HiC, CC=2')
run_cca(trainHiC, trainHiC, testHiC, testHiC, 10, 1, 'Train: HiC, Test: HiC, CC=10') 
run_cca(trainHiC, trainHiC, testHiC, testHiC, 20, 1, 'Train: HiC, Test: HiC, CC=20')
# Out:
# Training set: 1590
# Validation set: 454
# Test set: 228
# Training: (1590, 1589) Validation: (454, 1589) Test: (228, 1589)
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 2 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 20 components
# Training CCA, regularization = 1.0000, 20 components

# %% [markdown]
# ### CaptureC with different Diffusion Kernels

# %%
trainCaptureC_D10, valiCaptureC_D10, testCaptureC_D10 = train_vali_test(DiffKMatrix10CaptureC, 0.7, 0.2)
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testCaptureC_D1, 10, 1, 'Train: CaptureC-D1, Test: CaptureC-D1, CC=10') 
run_cca(trainCaptureC_D10, trainCaptureC_D10, testCaptureC_D10, testCaptureC_D10, 10, 1, 'Train: CaptureC-D10, Test: CaptureC-D10, CC=10')
# Out:
# Training set: 1590
# Validation set: 454
# Test set: 228
# Training: (1590, 1589) Validation: (454, 1589) Test: (228, 1589)
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %%
def run_cca(data1, data2, test1, test2, numCC,reg, title):
    cca = rcca.CCA(kernelcca=False, numCC=numCC, reg=reg)
    cca.train([data1, data2])
    # Find canonical components
    # Test on held-out data
    corrs = cca.validate([test1, test2])

    fig1 = plt.figure()
    ax = fig1.add_subplot(111)
    plot0 = ax.bar(np.arange(corrs[0].shape[0]), corrs[0], 0.3, color = "steelblue")
    #plot1 = ax.bar(np.arange(corrs[1].shape[0])+0.35, corrs[1], 0.3, color="orangered")
    #ax.legend([plot0[0], plot1[0]], ["Dataset 1", "Dataset 2"])
    ax.set_title(title+' CaptureC') 
    ax.set_ylabel("Prediction correlation")
    #ax.set_xticks(np.arange(0, corrs[0].shape[0], 20)+0.325)
    #ax.set_xticklabels(["%d" % i for i in range(0, corrs[0].shape[0], 20)])
    ax.set_xlabel("Test data")
    fig1.savefig(str(PROJDIR)+'/Prediction1.png', dpi=fig1.dpi)
    
    fig2 = plt.figure()
    ax = fig2.add_subplot(111)
    #plot0 = ax.bar(np.arange(corrs[0].shape[0]), corrs[0], 0.3, color = "steelblue")
    plot1 = ax.bar(np.arange(corrs[1].shape[0]), corrs[1], 0.3, color="orangered")
    #ax.legend([plot0[0], plot1[0]], ["Dataset 1", "Dataset 2"])
    ax.set_title(title+' HiC') 
    ax.set_ylabel("Prediction correlation")
    #ax.set_xticks(np.arange(0, corrs[0].shape[0], 20)+0.325)
    #ax.set_xticklabels(["%d" % i for i in range(0, corrs[0].shape[0], 20)])
    ax.set_xlabel("Test data")
    fig2.savefig(str(PROJDIR)+'/Prediction2.png', dpi=fig2.dpi)
    return cca.train([data1, data2])

# %% [markdown]
# ### Train on CaptureC+HiC

# %%
run_cca(trainCaptureC, trainHiC, testCaptureC, testHiC, 10, 1, 'Train: CaptureC-D1/CaptureC-D1, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ### Train on CaptureC_D1+HiC

# %%
run_cca(trainCaptureC_D1, trainHiC, testCaptureC_D1, testHiC, 10, 1, 'Train: CaptureC-D1/HiC, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ### Train on CaptureC_D1+HiC_D1

# %%
run_cca(trainCaptureC_D1, trainHiC_D1, testCaptureC_D1, testHiC_D1, 10, 1, 'Train: CaptureC-D1/HiC-D1, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ## Train on CaptureC_D1 only!

# %% [markdown]
# ### test CaptureC_D1, HiC_D1

# %%
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testHiC_D1, 10, 1, 'Train: CaptureC-D1, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ### test CaptureC, HiC_D1

# %%
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC, testHiC_D1, 10, 1, 'Train: CaptureC-D1, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ### test CaptureC_D1, HiC

# %%
run_cca(trainCaptureC_D1, trainCaptureC_D1, testCaptureC_D1, testHiC, 10, 1, 'Train: CaptureC-D1, Test:')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components

# %% [markdown]
# ### to do: check correlation between testCaptureC and testHiC

# %%
run_cca(trainCaptureC_D1, trainCaptureC_D10, testCaptureC_D1, testCaptureC_D10, 10, 1, 'Train: CaptureC-D1/D10, Test: CaptureC-D1/D10, CC=10')
# Out:
# Training CCA, regularization = 1.0000, 10 components
# Training CCA, regularization = 1.0000, 10 components
